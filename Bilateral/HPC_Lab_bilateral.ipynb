# %%
# !nvidia-smi
# Out:
# Mon Apr 13 18:34:51 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9c6c0284-deb6-4a92-9f3a-3dbde2697532" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9c6c0284-deb6-4a92-9f3a-3dbde2697532">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from PIL import Image

img = Image.open("kot.jpg")
gray = img.convert("L")
gray.save("input.bmp")

# %%
# %%writefile bilateral.cu
# Out:
# Writing bilateral.cu

# %%
# !nvcc -std=c++17 -arch=sm_75 bilateral.cu -o bilateral

# %%
# !./bilateral input.bmp 3.0 25.0
# Out:
# CPU time: 0.365468
# GPU time: 0.000279968
# MSE CPU-GPU: 0.0184262

# %%
# !./bilateral input.bmp 5.0 50.0
# Out:
# CPU time: 0.236565
# GPU time: 0.000332768
# MSE CPU-GPU: 0.0203223

# %%
# !./bilateral input.bmp 15.0 100.0
# Out:
# CPU time: 0.236314
# GPU time: 0.000232416
# MSE CPU-GPU: 0.0102782
